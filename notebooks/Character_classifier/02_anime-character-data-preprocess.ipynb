# %%
import os
from PIL import Image
from torchvision import transforms

# Paths
dataset_path = "/kaggle/input/anime-character-classification-2/moeimouto-faces"
output_path = "dataset_balanced/train"
os.makedirs(output_path, exist_ok=True)

# Parameters
target_size = 100     # every class will have at least this many images
img_size = (224, 224)

# Augmentation pipeline (PIL in -> PIL out)
augment = transforms.Compose([
    transforms.RandomHorizontalFlip(),
    transforms.RandomRotation(20),
    transforms.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2),
    transforms.RandomResizedCrop(img_size, scale=(0.8, 1.0)),
    transforms.ToTensor(),          # make it a Tensor
    transforms.ToPILImage()         # back to PIL for saving
])

# Loop through classes
for cls in os.listdir(dataset_path):
    class_folder = os.path.join(dataset_path, cls)
    if not os.path.isdir(class_folder):
        continue

    images = [f for f in os.listdir(class_folder) if f.lower().endswith(".png")]
    count = len(images)

    # Create output class folder
    out_folder = os.path.join(output_path, cls)
    os.makedirs(out_folder, exist_ok=True)

    # Copy original images
    for f in images:
        img_path = os.path.join(class_folder, f)
        Image.open(img_path).save(os.path.join(out_folder, f))

    # Augment if needed
    if count < target_size:
        idx = 0
        while count < target_size:
            img_path = os.path.join(class_folder, images[idx % len(images)])
            img = Image.open(img_path).convert("RGB")
            aug_img = augment(img)  # ✅ now works (PIL -> Tensor -> PIL)

            out_name = f"{cls}_aug_{count}.png"
            aug_img.save(os.path.join(out_folder, out_name))

            count += 1
            idx += 1

        print(f"Class {cls}: {len(images)} → {count} images (augmented)")
    else:
        print(f"Class {cls}: {len(images)} images (no augmentation needed)")
# Out:
# Class 083_shirou_kamui: 63 → 100 images (augmented)
# Class 161_ryougi_shiki: 49 → 100 images (augmented)
# Class 131_belldandy: 79 → 100 images (augmented)
# Class 087_suzumiya_haruka: 83 → 100 images (augmented)
# Class 007_nagato_yuki: 105 images (no augmentation needed)
# Class 094_fuyou_kaede: 107 images (no augmentation needed)
# Class 011_kirisame_marisa: 80 → 100 images (augmented)
# Class 091_komaki_manaka: 99 → 100 images (augmented)
# Class 153_canal_volphied: 73 → 100 images (augmented)
# Class 058_kochiya_sanae: 92 → 100 images (augmented)
# Class 065_sanzenin_nagi: 112 images (no augmentation needed)
# Class 179_siesta: 70 → 100 images (augmented)
# Class 136_shirley_fenette: 55 → 100 images (augmented)
# Class 175_saotome_alto: 40 → 100 images (augmented)
# Class 103_reinforce_zwei: 61 → 100 images (augmented)
# Class 152_maka_albarn: 50 → 100 images (augmented)
# Class 020_remilia_scarlet: 88 → 100 images (augmented)
# Class 074_daidouji_tomoyo: 118 images (no augmentation needed)
# Class 003_fate_testarossa: 81 → 100 images (augmented)
# Class 044_nakano_azusa: 110 images (no augmentation needed)
# Class 143_miura_azusa: 62 → 100 images (augmented)
# Class 137_sonsaku_hakufu: 57 → 100 images (augmented)
# Class 045_patchouli_knowledge: 90 → 100 images (augmented)
# Class 114_natsume_rin: 78 → 100 images (augmented)
# Class 075_katsura_hinagiku: 99 → 100 images (augmented)
# Class 037_lala_satalin_deviluke: 161 images (no augmentation needed)
# Class 199_kusugawa_sasara: 70 → 100 images (augmented)
# Class 016_furukawa_nagisa: 92 → 100 images (augmented)
# Class 052_ranka_lee: 124 images (no augmentation needed)
# Class 155_vivio: 51 → 100 images (augmented)
# Class 125_sakai_yuuji: 62 → 100 images (augmented)
# Class 022_kururugi_suzaku: 59 → 100 images (augmented)
# Class 178_milfeulle_sakuraba: 75 → 100 images (augmented)
# Class 174_hayama_mizuki: 47 → 100 images (augmented)
# Class 066_shameimaru_aya: 76 → 100 images (augmented)
# Class 051_houjou_reika: 129 images (no augmentation needed)
# Class 012_asahina_mikuru: 98 → 100 images (augmented)
# Class 088_vita: 95 → 100 images (augmented)
# Class 158_enma_ai: 50 → 100 images (augmented)
# Class 189_akizuki_ritsuko: 61 → 100 images (augmented)
# Class 010_izumi_konata: 112 images (no augmentation needed)
# Class 120_asakura_yume: 91 → 100 images (augmented)
# Class 064_amami_haruka: 135 images (no augmentation needed)
# Class 008_shana: 94 → 100 images (augmented)
# Class 027_izayoi_sakuya: 74 → 100 images (augmented)
# Class 084_okazaki_tomoya: 32 → 100 images (augmented)
# Class 196_kikuchi_makoto: 64 → 100 images (augmented)
# Class 081_yuzuhara_konomi: 117 images (no augmentation needed)
# Class 028_tainaka_ritsu: 86 → 100 images (augmented)
# Class 093_yuuki_mikan: 97 → 100 images (augmented)
# Class 127_setsuna_f_seiei: 81 → 100 images (augmented)
# Class 149_asakura_otome: 83 → 100 images (augmented)
# Class 118_noumi_kudryavka: 69 → 100 images (augmented)
# Class 195_erio_mondial: 69 → 100 images (augmented)
# Class 182_corticarte_apa_lagranges: 82 → 100 images (augmented)
# Class 181_allen_walker: 39 → 100 images (augmented)
# Class 029_kallen_stadtfeld: 115 images (no augmentation needed)
# Class 188_aika_granzchesta: 37 → 100 images (augmented)
# Class 002_suzumiya_haruhi: 102 images (no augmentation needed)
# Class 164_shindou_chihiro: 45 → 100 images (augmented)
# Class 017_louise: 119 images (no augmentation needed)
# Class 129_primula: 74 → 100 images (augmented)
# Class 070_nijihara_ink: 122 images (no augmentation needed)
# Class 172_kisaragi_chihaya: 49 → 100 images (augmented)
# Class 079_teana_lanster: 102 images (no augmentation needed)
# Class 076_cirno: 75 → 100 images (augmented)
# Class 034_sakagami_tomoyo: 114 images (no augmentation needed)
# Class 024_fujibayashi_kyou: 77 → 100 images (augmented)
# Class 191_shidou_hikaru: 59 → 100 images (augmented)
# Class 009_hakurei_reimu: 100 images (no augmentation needed)
# Class 180_matsuoka_miu: 46 → 100 images (augmented)
# Class 035_yoko: 77 → 100 images (augmented)
# Class 040_flandre_scarlet: 64 → 100 images (augmented)
# Class 106_nia: 65 → 100 images (augmented)
# Class 186_nanael: 41 → 100 images (augmented)
# Class 006_akiyama_mio: 76 → 100 images (augmented)
# Class 004_takamachi_nanoha: 108 images (no augmentation needed)
# Class 197_illyasviel_von_einzbern: 47 → 100 images (augmented)
# Class 116_pastel_ink: 87 → 100 images (augmented)
# Class 036_reisen_udongein_inaba: 95 → 100 images (augmented)
# Class 156_miyafuji_yoshika: 72 → 100 images (augmented)
# Class 192_shirakawa_kotori: 74 → 100 images (augmented)
# Class 095_nerine: 99 → 100 images (augmented)
# Class 185_akihime_sumomo: 87 → 100 images (augmented)
# Class 111_suigintou: 66 → 100 images (augmented)
# Class 023_hiiragi_tsukasa: 110 images (no augmentation needed)
# Class 150_maria: 63 → 100 images (augmented)
# Class 047_sheryl_nome: 81 → 100 images (augmented)
# Class 025_souryuu_asuka_langley: 80 → 100 images (augmented)
# Class 104_fukuzawa_yumi: 44 → 100 images (augmented)
# Class 031_kotobuki_tsumugi: 89 → 100 images (augmented)
# Class 193_kagurazaka_asuna: 60 → 100 images (augmented)
# Class 166_katsura_kotonoha: 87 → 100 images (augmented)
# Class 090_minase_iori: 80 → 100 images (augmented)
# Class 059_sairenji_haruna: 149 images (no augmentation needed)
# Class 113_lisianthus: 80 → 100 images (augmented)
# Class 176_sendou_erika: 69 → 100 images (augmented)
# Class 134_nunnally_lamperouge: 37 → 100 images (augmented)
# Class 173_reina: 52 → 100 images (augmented)
# Class 107_chii: 72 → 100 images (augmented)
# Class 098_mizunashi_akari: 91 → 100 images (augmented)
# Class 159_andou_mahoro: 75 → 100 images (augmented)
# Class 085_sonozaki_mion: 111 images (no augmentation needed)
# Class 105_yuno: 104 images (no augmentation needed)
# Class 056_nagi: 89 → 100 images (augmented)
# Class 139_caro_ru_lushe: 89 → 100 images (augmented)
# Class 072_melon-chan: 130 images (no augmentation needed)
# Class 042_tsukimura_mayu: 151 images (no augmentation needed)
# Class 021_hirasawa_yui: 85 → 100 images (augmented)
# Class 102_katagiri_yuuhi: 95 → 100 images (augmented)
# Class 068_miyamura_miyako: 135 images (no augmentation needed)
# Class 013_saber: 83 → 100 images (augmented)
# Class 026_tohsaka_rin: 79 → 100 images (augmented)
# Class 001_kinomoto_sakura: 141 images (no augmentation needed)
# Class 041_saigyouji_yuyuko: 64 → 100 images (augmented)
# Class 123_midori: 97 → 100 images (augmented)
# Class 055_ibuki_fuuko: 97 → 100 images (augmented)
# Class 190_kawashima_ami: 60 → 100 images (augmented)
# Class 132_minamoto_chizuru: 60 → 100 images (augmented)
# Class 054_horo: 112 images (no augmentation needed)
# Class 078_black_rock_shooter: 40 → 100 images (augmented)
# Class 100_houjou_satoko: 87 → 100 images (augmented)
# Class 014_hiiragi_kagami: 110 images (no augmentation needed)
# Class 096_golden_darkness: 103 images (no augmentation needed)
# Class 144_kotegawa_yui: 99 → 100 images (augmented)
# Class 198_nogizaka_haruka: 60 → 100 images (augmented)
# Class 039_yagami_hayate: 117 images (no augmentation needed)
# Class 169_shihou_matsuri: 74 → 100 images (augmented)
# Class 138_kanu: 75 → 100 images (augmented)
# Class 032_yakumo_yukari: 60 → 100 images (augmented)
# Class 049_kyon: 66 → 100 images (augmented)
# Class 998_ito_nobue: 38 → 100 images (augmented)
# Class 069_hayase_mitsuki: 86 → 100 images (augmented)
# Class 168_asagiri_mai: 67 → 100 images (augmented)
# Class 146_shinku: 68 → 100 images (augmented)
# Class 043_konpaku_youmu: 83 → 100 images (augmented)
# Class 119_takatsuki_yayoi: 75 → 100 images (augmented)
# Class 154_kobayakawa_yutaka: 59 → 100 images (augmented)
# Class 171_ikari_shinji: 43 → 100 images (augmented)
# Class 033_kagamine_len: 66 → 100 images (augmented)
# Class 165_rollo_lamperouge: 57 → 100 images (augmented)
# Class 160_ayasaki_hayate: 58 → 100 images (augmented)
# Class 140_seto_san: 65 → 100 images (augmented)
# Class 184_suzumiya_akane: 61 → 100 images (augmented)
# Class 121_arcueid_brunestud: 74 → 100 images (augmented)
# Class 157_ogasawara_sachiko: 45 → 100 images (augmented)
# Class 030_aisaka_taiga: 45 → 100 images (augmented)
# Class 038_takara_miyuki: 111 images (no augmentation needed)
# Class 005_lelouch_lamperouge: 75 → 100 images (augmented)
# Class 112_hinamori_amu: 134 images (no augmentation needed)
# Class 057_li_syaoran: 97 → 100 images (augmented)
# Class 060_ichinose_kotomi: 118 images (no augmentation needed)
# Class 050_megurine_luka: 97 → 100 images (augmented)
# Class 063_ryuuguu_rena: 93 → 100 images (augmented)
# Class 080_koizumi_itsuki: 57 → 100 images (augmented)
# Class 018_kagamine_rin: 79 → 100 images (augmented)
# Class 092_shindou_kei: 80 → 100 images (augmented)
# Class 061_furude_rika: 112 images (no augmentation needed)
# Class 000_hatsune_miku: 64 → 100 images (augmented)
# Class 073_subaru_nakajima: 146 images (no augmentation needed)
# Class 053_kousaka_tamaki: 161 images (no augmentation needed)
# Class 071_nagase_minato: 130 images (no augmentation needed)
# Class 019_ayanami_rei: 79 → 100 images (augmented)
# Class 015_c.c: 101 images (no augmentation needed)
# Class 089_shigure_asa: 106 images (no augmentation needed)
# Class 997_ana_coppola: 44 → 100 images (augmented)
# Class 086_tsuruya: 82 → 100 images (augmented)
# Class 999_ito_chika: 51 → 100 images (augmented)
# Class 046_alice_margatroid: 115 images (no augmentation needed)
# Class 077_yoshida_kazumi: 86 → 100 images (augmented)
# Class 097_kamikita_komari: 107 images (no augmentation needed)
# Class 062_matou_sakura: 92 → 100 images (augmented)
# Class 067_feena_fam_earthlight: 128 images (no augmentation needed)

# %%
class_counts = {}
for cls in os.listdir(dataset_path):
    cls_path = os.path.join(dataset_path, cls)
    if os.path.isdir(cls_path):
        count = len([f for f in os.listdir(cls_path) if f.lower().endswith(('.jpg','.jpeg','.png'))])
        class_counts[cls] = count

sorted_counts = sorted(class_counts.items(), key=lambda x: x[1], reverse=True)

print("Total classes:", len(sorted_counts))
print("Total images:", sum(c for _, c in sorted_counts))
print("Average images per class:", sum(c for _, c in sorted_counts)//len(sorted_counts))

print("\nTop 10 classes by image count:")
for cls, count in sorted_counts[:10]:
    print(f"{cls}: {count}")

print("\nBottom 10 classes by image count:")
for cls, count in sorted_counts[-10:]:
    print(f"{cls}: {count}")
# Out:
# Total classes: 173
# Total images: 14397
# Average images per class: 83
#
# Top 10 classes by image count:
# 037_lala_satalin_deviluke: 161
# 053_kousaka_tamaki: 161
# 042_tsukimura_mayu: 151
# 059_sairenji_haruna: 149
# 073_subaru_nakajima: 146
# 001_kinomoto_sakura: 141
# 064_amami_haruka: 135
# 068_miyamura_miyako: 135
# 112_hinamori_amu: 134
# 072_melon-chan: 130
#
# Bottom 10 classes by image count:
# 997_ana_coppola: 44
# 171_ikari_shinji: 43
# 186_nanael: 41
# 175_saotome_alto: 40
# 078_black_rock_shooter: 40
# 181_allen_walker: 39
# 998_ito_nobue: 38
# 188_aika_granzchesta: 37
# 134_nunnally_lamperouge: 37
# 084_okazaki_tomoya: 32

# %%
print("After augmentation ")
class_counts = {}
for cls in os.listdir("/kaggle/working/dataset_balanced/train"):
    cls_path = os.path.join("/kaggle/working/dataset_balanced/train", cls)
    if os.path.isdir(cls_path):
        count = len([f for f in os.listdir(cls_path) if f.lower().endswith(('.jpg','.jpeg','.png'))])
        class_counts[cls] = count

sorted_counts = sorted(class_counts.items(), key=lambda x: x[1], reverse=True)

print("Total classes:", len(sorted_counts))
print("Total images:", sum(c for _, c in sorted_counts))
print("Average images per class:", sum(c for _, c in sorted_counts)//len(sorted_counts))

print("\nTop 10 classes by image count:")
for cls, count in sorted_counts[:10]:
    print(f"{cls}: {count}")

print("\nBottom 10 classes by image count:")
for cls, count in sorted_counts[-10:]:
    print(f"{cls}: {count}")
# Out:
# After augmentation
# Total classes: 173
# Total images: 18154
# Average images per class: 104
#
# Top 10 classes by image count:
# 037_lala_satalin_deviluke: 161
# 053_kousaka_tamaki: 161
# 042_tsukimura_mayu: 151
# 059_sairenji_haruna: 149
# 073_subaru_nakajima: 146
# 001_kinomoto_sakura: 141
# 064_amami_haruka: 135
# 068_miyamura_miyako: 135
# 112_hinamori_amu: 134
# 072_melon-chan: 130
#
# Bottom 10 classes by image count:
# 121_arcueid_brunestud: 100
# 041_saigyouji_yuyuko: 100
# 090_minase_iori: 100
# 143_miura_azusa: 100
# 146_shinku: 100
# 184_suzumiya_akane: 100
# 012_asahina_mikuru: 100
# 176_sendou_erika: 100
# 069_hayase_mitsuki: 100
# 191_shidou_hikaru: 100
